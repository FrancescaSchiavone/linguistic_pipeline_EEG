# %%
import pandas as pd
all_surp = []
stories = ['01_D', '02_D', '03_D', '04_D', '05_D', '06_D', '07_D', '08_D', '09_D', '10_D']

for story in stories:
    df= pd.read_csv (f'C:\Users\schia\OneDrive - Alma Mater Studiorum Università di Bologna\Desktop\IMT\TESI\linguistic_pipeline_EEG\output\output_D\St{story}\surprisal_entropyN_St{story}.csv')
    print(df.dtypes)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'venv (Python 3.13.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
